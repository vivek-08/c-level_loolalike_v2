# %%
import pandas as pd
import numpy as np
from google.cloud import bigquery, bigquery_storage
from utils import *
import warnings 

### Graphs
from plotly.subplots import make_subplots
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as pyo
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Helper function to calculate proportion of records in each category

# %%
def unseen_eda(input_df, cat_col_name):
    
    df_cat = pd.pivot_table(
        input_df, 
        values='ga_pageviews',
        columns= cat_col_name,
        index='c_level',
        aggfunc='sum')\
        .reset_index()

    df_cat = df_cat.fillna(0)
    df_cat = df_cat.T
    
    new_header = df_cat.iloc[0] # grab the first row for the header
    df_cat = df_cat[1:] # take the data minus the header row
    df_cat.columns = new_header

    df_cat['% of c-level pvs'] = (df_cat['C-level'] / df_cat['C-level'].sum()) * 100
    df_cat['% of non-c-level pvs'] = (df_cat['Non-Clevel'] / df_cat['Non-Clevel'].sum()) * 100

    df_cat.drop(['C-level', 'Non-Clevel'], axis=1, inplace=True)

    df_cat['c_rank'] = df_cat['% of c-level pvs'].rank(ascending=False).astype(int)
    df_cat['nonc_rank'] = df_cat['% of non-c-level pvs'].rank(ascending=False).astype(int)
    df_cat = df_cat.sort_values('c_rank')
    
    return df_cat

# %%
# #Reading the datasets
# df_train = pd.read_csv('Data/train_data_raw.csv')
# df_pred = pd.read_pickle('Data/sample_prediction_data_feb_april_raw_july13.pkl')

# %%
query_predictions = """
    SELECT * FROM 
    `api-project-901373404215.lookalike_trail_data.sample_predicted_feb_april_new`""" 
query_raw = """
    SELECT * FROM 
    `api-project-901373404215.lookalike_trail_data.sample_prediction_data_feb_april_raw`""" 
query_train_raw = """
   SELECT
        * from
        `api-project-901373404215.lookalike_data.c_level_version_1a_raw_3`"""

# %%
bqclient = bigquery.Client()
bqstorageclient = bigquery_storage.BigQueryReadClient()


df_train = bqclient.query(query_train_raw).result().to_dataframe(bqstorage_client=bqstorageclient)
df_pred = bqclient.query(query_raw).result().to_dataframe(bqstorage_client=bqstorageclient)
predictions = bqclient.query(query_predictions).result().to_dataframe(bqstorage_client=bqstorageclient)

# %%
df_pred.columns = df_pred.columns.str.lower()

# %%
pred = pd.merge(df_pred,predictions, on='ga_fullvisitorid')

# %%
print("Training Dataframe Shape::",df_train.shape)
print("Prediction Dataframe Shape::",pred.shape)
# Out:
# Training Dataframe Shape:: (2298702, 16)
# Prediction Dataframe Shape:: (2282548, 25)

# %%
# Creating Target columns
df_train['c_level'] = np.where(df_train['managementlevel'] == 'C-Level', 'C-level','Non-Clevel')
pred['c_level'] = np.where(pred['predicted'] == 1, 'C-level','Non-Clevel' )

# %% [markdown]
# ### Tier 1

# %%
tier1_eda_train = unseen_eda(df_train, 'tier1')
tier1_eda_pred = unseen_eda(pred, 'tier1')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'tier1', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred')
# Out:
# c_level                  % of c-level pvs_train % of non-c-level pvs_train  \
# tier1
# Style and Fashion                       0.81724                   1.206311
# Shopping                               0.614262                   0.964379
# Business and Finance                  28.114899                   28.58851
# News and Politics                      9.812799                   7.035828
# Technology and Computing               3.537489                   4.698698
# Video Gaming                           0.483552                   0.593838
# Personal Finance                       6.491517                   5.544902
# Movies                                 0.738063                   0.728473
# Fine Art                               0.206136                    0.24528
# Travel                                 2.562685                   2.124547
# Real Estate                            1.282823                   1.014373
# Sports                                 2.335422                   2.223808
# Television                             0.195672                   0.360052
# Medical Health                         0.963944                   1.139244
# Science                                1.160405                   1.065314
# Education                              1.091101                   1.301276
# Food and Drink                         0.978555                   1.367115
# Careers                                4.212368                   4.953519
# Automotive                             0.763731                   0.684729
# Music and Audio                        0.510207                   0.425389
# Healthy Living                         1.016465                   0.996295
# Books and Literature                   0.051337                   0.034203
#
# c_level                   c_rank_train  nonc_rank_train % of c-level pvs_pred  \
# tier1
# Style and Fashion                   15               11             52.547573
# Shopping                            18               16             13.190214
# Business and Finance                 2                2             10.391336
# News and Politics                    3                3              4.660717
# Technology and Computing             6                6              3.112681
# Video Gaming                        20               19              2.908141
# Personal Finance                     4                4              2.524409
# Movies                              17               17              1.717612
# Fine Art                            21               22              1.318147
# Travel                               7                8              1.205388
# Real Estate                          9               14              0.841761
# Sports                               8                7              0.823405
# Television                          22               21              0.790189
# Medical Health                      14               12              0.765714
# Science                             10               13              0.752603
# Education                           11               10              0.728128
# Food and Drink                      13                9              0.471141
# Careers                              5                5              0.465023
# Automotive                          16               18              0.280587
# Music and Audio                     19               20              0.256112
# Healthy Living                      12               15              0.232511
# Books and Literature                23               23              0.016608
#
# c_level                  % of non-c-level pvs_pred  c_rank_pred  \
# tier1
# Style and Fashion                        15.196243            1
# Shopping                                  8.802332            2
# Business and Finance                     17.044177            3
# News and Politics                          9.85933            4
# Technology and Computing                   4.41784            5
# Video Gaming                              3.836782            6
# Personal Finance                          5.829345            7
# Movies                                    1.532574            8
# Fine Art                                  2.655362            9
# Travel                                    4.837232           10
# Real Estate                               0.835974           11
# Sports                                     1.97018           12
# Television                                0.995466           13
# Medical Health                            1.299679           14
# Science                                   1.872582           15
# Education                                 1.804889           16
# Food and Drink                            3.126679           17
# Careers                                   8.070843           18
# Automotive                                0.742907           19
# Music and Audio                           0.415404           20
# Healthy Living                            4.765098           21
# Books and Literature                       0.08908           22
#
# c_level                   nonc_rank_pred
# tier1
# Style and Fashion                      2
# Shopping                               4
# Business and Finance                   1
# News and Politics                      3
# Technology and Computing               9
# Video Gaming                          10
# Personal Finance                       6
# Movies                                16
# Fine Art                              12
# Travel                                 7
# Real Estate                           19
# Sports                                13
# Television                            18
# Medical Health                        17
# Science                               14
# Education                             15
# Food and Drink                        11
# Careers                                5
# Automotive                            20
# Music and Audio                       21
# Healthy Living                         8
# Books and Literature                  22

# %% [markdown]
# ### Primary Channel

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_primarychannel')
tier1_eda_pred = unseen_eda(pred, 'ga_primarychannel')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_primarychannel', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred').head(20)
# Out:
# c_level           % of c-level pvs_train % of non-c-level pvs_train  \
# ga_primarychannel
# lifestyle                        6.80388                   8.054468
# innovation                     12.297689                  14.258956
# business                       17.662959                  17.155898
# billionaires                    4.143261                   3.037436
# none                            9.399342                   8.536994
# leadership                     21.607389                  23.819923
# home                            7.893599                   5.562608
# money                          10.273052                   9.764568
# small business                  3.553087                   3.066953
# asia                            0.429846                   0.588818
# forbes vetted                   1.326065                   1.972174
# real estate                     1.003039                    0.79359
# consumer                        0.061801                   0.063719
# 404                              0.23062                   0.265144
# entrepreneurs                   0.199226                   0.191437
# newsletters                     2.328314                   1.867835
# lists                            0.05726                   0.079175
# tech                            0.154997                   0.159298
# investing                       0.063973                   0.071866
# forbes magazine                 0.019153                   0.025276
#
# c_level            c_rank_train  nonc_rank_train % of c-level pvs_pred  \
# ga_primarychannel
# lifestyle                     7                6             71.175375
# innovation                    3                3              7.258396
# business                      2                2              5.787012
# billionaires                  8                9              4.470453
# none                          5                5              3.589138
# leadership                    1                1              2.421992
# home                          6                7              2.290985
# money                         4                4               1.86332
# small business                9                8              0.313982
# asia                         13               13              0.312899
# forbes vetted                11               10              0.217622
# real estate                  12               12              0.102856
# consumer                     20               21              0.035729
# 404                          15               15              0.034646
# entrepreneurs                16               16               0.02815
# newsletters                  10               11              0.025985
# lists                        22               19              0.023819
# tech                         17               17              0.014075
# investing                    19               20              0.008662
# forbes magazine              27               25              0.006496
#
# c_level           % of non-c-level pvs_pred  c_rank_pred  nonc_rank_pred
# ga_primarychannel
# lifestyle                         24.175766            1               1
# innovation                         8.623472            2               5
# business                          10.266256            3               4
# billionaires                       6.119803            4               7
# none                              11.014777            5               3
# leadership                           6.8549            6               6
# home                               4.986793            7               8
# money                             22.254741            8               2
# small business                     1.212272            9              10
# asia                               0.562647           10              12
# forbes vetted                      0.695147           11              11
# real estate                        0.312074           12              13
# consumer                             0.0652           13              20
# 404                                0.139029           14              16
# entrepreneurs                      0.151996           15              14
# newsletters                        0.082367           16              18
# lists                              0.143686           17              15
# tech                                0.11862           18              17
# investing                           0.07424           19              19
# forbes magazine                    1.852309           20               9

# %% [markdown]
# ### Device Category

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_devicecategory')
tier1_eda_pred = unseen_eda(pred, 'ga_devicecategory')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_devicecategory', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred')
# Out:
# c_level           % of c-level pvs_train % of non-c-level pvs_train  \
# ga_devicecategory
# desktop                        80.345305                  89.261786
# mobile                         19.654695                  10.738214
#
# c_level            c_rank_train  nonc_rank_train % of c-level pvs_pred  \
# ga_devicecategory
# desktop                       1                1             57.703498
# mobile                        2                2             42.296502
#
# c_level           % of non-c-level pvs_pred  c_rank_pred  nonc_rank_pred
# ga_devicecategory
# desktop                           73.555506            1               1
# mobile                            26.444494            2               2

# %% [markdown]
# ### Primary Section

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_primarysection')
tier1_eda_pred = unseen_eda(pred, 'ga_primarysection')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_primarysection', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred').head(25)
# Out:
# c_level                   % of c-level pvs_train % of non-c-level pvs_train  \
# ga_primarysection
# none                                   43.863042                  39.976339
# rtb                                      0.07819                   0.093234
# crypto & blockchain                     1.589146                   1.344842
# hollywood & entertainment               0.829412                   1.242374
# markets                                  1.46127                   1.314901
# leadership strategy                     3.559742                   3.562814
# travel                                  2.679259                   2.621297
# aerospace & defense                     1.218385                   0.895181
# entrepreneurs                           1.369817                    1.27472
# investing                               1.621808                   1.441265
# consumer tech                           0.715987                   0.952207
# personal finance                        1.377933                   1.449716
# games                                   0.543374                   0.963791
# healthcare                               1.32508                   1.507581
# cybersecurity                           0.897111                   0.802506
# forbeslife                              0.678178                   0.779953
# forbeswomen                             3.668417                   3.355248
# breaking news                           0.061167                   0.151995
# venture capital                         1.502444                    1.16923
# careers                                 4.598388                   5.935356
# vices                                   0.950558                    1.09161
# education                               0.833173                   1.004756
# energy                                  0.649871                   0.875034
# arts                                    0.314147                   0.401477
# sportsmoney                             2.070561                   2.458669
#
# c_level                    c_rank_train  nonc_rank_train  \
# ga_primarysection
# none                                  1                1
# rtb                                  62               64
# crypto & blockchain                   8               12
# hollywood & entertainment            25               16
# markets                              11               14
# leadership strategy                   4                3
# travel                                5                5
# aerospace & defense                  15               26
# entrepreneurs                        13               15
# investing                             7               11
# consumer tech                        31               23
# personal finance                     12               10
# games                                37               22
# healthcare                           14                8
# cybersecurity                        22               29
# forbeslife                           32               30
# forbeswomen                           3                4
# breaking news                        69               55
# venture capital                      10               17
# careers                               2                2
# vices                                20               18
# education                            24               20
# energy                               33               27
# arts                                 46               46
# sportsmoney                           6                6
#
# c_level                   % of c-level pvs_pred % of non-c-level pvs_pred  \
# ga_primarysection
# none                                  64.913687                 34.074427
# rtb                                   11.841986                  5.197333
# crypto & blockchain                    2.145212                  1.128618
# hollywood & entertainment                1.7741                  1.725106
# markets                                1.708153                  2.157592
# leadership strategy                    1.503847                  0.938029
# travel                                 1.245232                    0.9596
# aerospace & defense                    0.921963                   0.90301
# entrepreneurs                          0.921963                  0.484638
# investing                              0.875412                  2.395406
# consumer tech                          0.676279                  0.949037
# personal finance                       0.610332                  2.569794
# games                                  0.589642                  3.006763
# healthcare                             0.570246                  0.656186
# cybersecurity                          0.481024                  0.556542
# forbeslife                             0.481024                  0.263557
# forbeswomen                            0.481024                  0.719523
# breaking news                          0.473266                  0.177717
# venture capital                          0.4668                  0.176962
# careers                                0.434473                  1.053164
# vices                                  0.354303                  0.262714
# education                              0.347837                  0.506209
# energy                                  0.31551                  0.247978
# arts                                   0.314217                  0.263468
# sportsmoney                            0.309045                  0.879353
#
# c_level                    c_rank_pred  nonc_rank_pred
# ga_primarysection
# none                                 1               1
# rtb                                  2               3
# crypto & blockchain                  3              12
# hollywood & entertainment            4              11
# markets                              5               8
# leadership strategy                  6              16
# travel                               7              14
# aerospace & defense                  8              17
# entrepreneurs                        8              25
# investing                           10               7
# consumer tech                       11              15
# personal finance                    12               6
# games                               13               5
# healthcare                          14              20
# cybersecurity                       16              21
# forbeslife                          16              29
# forbeswomen                         16              19
# breaking news                       18              39
# venture capital                     19              40
# careers                             20              13
# vices                               21              31
# education                           22              23
# energy                              23              33
# arts                                24              30
# sportsmoney                         25              18

# %% [markdown]
# ### DeviceOS

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_deviceoperatingsystem')
tier1_eda_pred = unseen_eda(pred, 'ga_deviceoperatingsystem')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_deviceoperatingsystem', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred')
# Out:
# c_level                  % of c-level pvs_train % of non-c-level pvs_train  \
# ga_deviceoperatingsystem
# ios                                   15.264947                   7.679578
# macintosh                             39.558016                  34.526176
# android                                5.231632                   3.469904
# windows                               39.630268                  53.953365
# linux                                  0.046914                   0.051094
# chrome os                              0.267431                   0.300519
# blackberry                             0.000594                   0.016285
# (not set)                              0.000198                   0.003078
#
# c_level                   c_rank_train  nonc_rank_train % of c-level pvs_pred  \
# ga_deviceoperatingsystem
# ios                                  3                3             49.326954
# macintosh                            2                2             30.118316
# android                              4                4              10.60322
# windows                              1                1              4.711967
# linux                                6                6              4.643434
# chrome os                            5                5              0.596108
# blackberry                           7                7                   0.0
# (not set)                            8                8                   0.0
#
# c_level                  % of non-c-level pvs_pred  c_rank_pred  \
# ga_deviceoperatingsystem
# ios                                       9.802661            1
# macintosh                                31.232376            2
# android                                  17.716568            3
# windows                                  39.968025            4
# linux                                     0.534305            5
# chrome os                                 0.721165            6
# blackberry                                0.002663           10
# (not set)                                 0.020195           10
#
# c_level                   nonc_rank_pred
# ga_deviceoperatingsystem
# ios                                    4
# macintosh                              2
# android                                3
# windows                                1
# linux                                  6
# chrome os                              5
# blackberry                             8
# (not set)                              7

# %% [markdown]
# ### Device Browser

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_devicebrowser')
tier1_eda_pred = unseen_eda(pred, 'ga_devicebrowser')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_devicebrowser', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred')

# %% [markdown]
# ### Country

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_country')
tier1_eda_pred = unseen_eda(pred, 'ga_country')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_country', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred').head(20)
# Out:
# c_level            % of c-level pvs_train % of non-c-level pvs_train  \
# ga_country
# united states                   84.462476                  87.747998
# canada                           4.254944                   2.610767
# malaysia                         0.125501                   0.110862
# india                            0.694014                   0.836865
# united kingdom                    1.48641                   1.938432
# germany                          0.215568                   0.149196
# belgium                          0.101153                   0.019419
# south africa                     0.376304                   0.271475
# austria                          0.028703                   0.009514
# indonesia                        0.034443                   0.030332
# china                             0.09759                    0.05725
# south korea                      0.014846                   0.052997
# nigeria                          0.053051                    0.04505
# vietnam                           0.03385                   0.035592
# brazil                           0.180333                   0.086294
# ghana                            0.064532                   0.010521
# russia                           0.035631                   0.012927
# slovakia                         0.002771                   0.019643
# dominican republic               0.041372                   0.023336
# netherlands                      0.173405                   0.104146
#
# c_level             c_rank_train  nonc_rank_train % of c-level pvs_pred  \
# ga_country
# united states                  1                1             31.264135
# canada                         2                2             25.481094
# malaysia                      20               20              6.398048
# india                          6                5              3.517438
# united kingdom                 4                3              2.394556
# germany                       14               16              2.277507
# belgium                       23               56              1.966036
# south africa                   9                9               1.55537
# austria                       58               76               1.48395
# indonesia                     49               44              1.470063
# china                         24               28              1.378804
# south korea                   74               30              1.271674
# nigeria                       37               33              1.063365
# vietnam                       50               40              0.997897
# brazil                        15               25              0.843154
# ghana                         33               75              0.825299
# russia                        48               68              0.745943
# slovakia                     119               55              0.710233
# dominican republic            45               49              0.694362
# netherlands                   16               21              0.626909
#
# c_level            % of non-c-level pvs_pred  c_rank_pred  nonc_rank_pred
# ga_country
# united states                      27.802715            1               1
# canada                              5.643633            2               4
# malaysia                             0.58475            3              17
# india                              11.457971            4               3
# united kingdom                     26.728481            5               2
# germany                              0.38207            6              22
# belgium                             0.187022            7              34
# south africa                        0.578609            8              18
# austria                             0.097414            9              48
# indonesia                           0.706638           10              14
# china                               0.340885           11              26
# south korea                         2.166933           12               8
# nigeria                             0.363166           13              24
# vietnam                             0.188908           14              33
# brazil                              0.483432           15              21
# ghana                               0.049387           16              60
# russia                              0.876116           17              12
# slovakia                             0.11838           18              45
# dominican republic                  0.027413           19              86
# netherlands                         0.264918           20              28

# %% [markdown]
# ### Referral Group

# %%
tier1_eda_train = unseen_eda(df_train, 'ga_referralgroup')
tier1_eda_pred = unseen_eda(df_pred, 'ga_referralgroup')
pd.merge(tier1_eda_train, tier1_eda_pred, on = 'ga_referralgroup', suffixes = ("_train", "_pred")).sort_values(by = 'c_rank_pred')
# Out:
# c_level                 % of c-level pvs_train % of non-c-level pvs_train  \
# ga_referralgroup
# organic search                       43.312938                  56.086603
# direct                                3.520746                    2.63332
# referral                              11.57713                  10.469817
# content aggregators                   1.186713                   0.611391
# push notification                      5.21639                   3.067366
# organic social (dark)                  4.47942                   3.166531
# organic social (forbes)               2.035722                   1.413839
# paid search                            0.02415                   0.016341
# newsletter                           28.598689                    22.2242
# fbia                                  0.045727                    0.30841
# paid web                              0.001188                   0.001791
# paid social (dark)                    0.000396                    0.00028
#
# c_level                  c_rank_train  nonc_rank_train % of c-level pvs_pred  \
# ga_referralgroup
# organic search                      1                1             39.696935
# direct                              6                6             23.369017
# referral                            3                3             15.103769
# content aggregators                 8                8             11.582169
# push notification                   4                5              3.090092
# organic social (dark)               5                4              2.799056
# organic social (forbes)             7                7              2.098521
# paid search                        10               10              1.644582
# newsletter                          2                2              0.369404
# fbia                                9                9              0.218838
# paid web                           11               11              0.018225
# paid social (dark)                 13               12               0.00028
#
# c_level                 % of non-c-level pvs_pred  c_rank_pred  nonc_rank_pred
# ga_referralgroup
# organic search                          39.314329            1               1
# direct                                  24.345534            2               2
# referral                                14.949068            3               3
# content aggregators                     11.241685            4               4
# push notification                        3.001093            5               5
# organic social (dark)                    2.707471            6               6
# organic social (forbes)                  2.072609            7               7
# paid search                              1.747015            8               8
# newsletter                               0.383478            9               9
# fbia                                     0.209456           10              10
# paid web                                  0.01948           11              11
# paid social (dark)                       0.000433           13              13

# %% [markdown]
# ### TimeonPage

# %%
cat_col_name = 'timeonpage'

df_cat = pd.pivot_table(
    df_train, 
    values='ga_pageviews',
    columns= cat_col_name,
    index='c_level',
    aggfunc='sum')\
    .reset_index()

df_cat = df_cat.fillna(0)
df_cat = df_cat.T

df_top = df_train.groupby('c_level').sum()
df_top['avg_time_on_page'] = df_top['timeonpage'] / df_top['ga_pageviews']
df_top[['avg_time_on_page']]

cat_col_name = 'timeonpage'

df_cat = pd.pivot_table(
    df_pred, 
    values='ga_pageviews',
    columns= cat_col_name,
    index='c_level',
    aggfunc='sum')\
    .reset_index()

df_cat = df_cat.fillna(0)
df_cat = df_cat.T

df_top2 = df_pred.groupby('c_level').sum()
df_top2['avg_time_on_page'] = df_top2['timeonpage'] / df_top2['ga_pageviews']
df_top2[['avg_time_on_page']]

pd.merge(df_top[['avg_time_on_page']], df_top2[['avg_time_on_page']], on = 'c_level', suffixes = ('_train','_pred'))
# Out:
#             avg_time_on_page_train  avg_time_on_page_pred
# c_level
# C-level                 130.106050              95.702711
# Non-Clevel              140.572768              96.633319
